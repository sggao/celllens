# %%
#!pip install PhenoGraph

# %%
import muse_sc as muse
import phenograph
from sklearn.decomposition import PCA
import numpy as np
from sklearn.metrics.cluster import adjusted_rand_score
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
np.random.seed(0)
# Out:
# WARNING:tensorflow:From /home/bokai/miniconda3/envs/muse/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import sys
sys.executable
# Out:
# '/home/bokai/miniconda3/envs/muse/bin/python'

# %%
import pandas as pd

###### process protein modality

data1 = pd.read_csv("../data/Xton_sub_norm.csv")
dataa = data1

## change to scaled version
from scipy.stats import zscore
dataa = dataa.apply(zscore)
dataa = dataa

####### process imaging modality

datab_full = np.load('../data/muse_images/Inception_img_feature_xton.npy')
datab_full = np.array(datab_full).squeeze(1)

###### this is pca on feature mod and image mod

latent_dim = 20
view_a_feature = PCA(n_components=latent_dim).fit_transform(dataa)
### this is pca on img mod
latent_dim = 100
view_b_feature = PCA(n_components=latent_dim).fit_transform(datab_full)
### then default clustering

# already finished running
view_a_label, _, _ = phenograph.cluster(view_a_feature, n_jobs = 16)
view_b_label, _, _ = phenograph.cluster(view_b_feature, n_jobs = 16)
# Out:
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm

# %%
np.save('../data/musexton_a_label.npy', view_a_label)
np.save('../data/musexton_b_label.npy', view_b_label)

# %%
view_a_label = np.load('../data/musexton_a_label.npy')
view_b_label = np.load('../data/musexton_b_label.npy')

# %% [markdown]
# ### change original muse function phenograph cpu allocation too many issue

# %%
import numpy as np
from muse_sc.muse_architecture import structured_embedding
from scipy.spatial.distance import pdist
import phenograph
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

def muse_fit_predict(data_x,
                     data_y,
                     label_x,
                     label_y,
                     latent_dim=100,
                     n_epochs=500,
                     lambda_regul=5,
                     lambda_super=5):
    """
        MUSE model fitting and predicting:
          This function is used to train the MUSE model on multi-modality data

        Parameters:
          data_x:       input for transcript modality; matrix of  n * p, where n = number of cells, p = number of genes.
          data_y:       input for morphological modality; matrix of n * q, where n = number of cells, q is the feature dimension.
          label_x:      initial reference cluster label for transcriptional modality.
          label_y:      inital reference cluster label for morphological modality.
          latent_dim:   feature dimension of joint latent representation.
          n_epochs:     maximal epoch used in training.
          lambda_regul: weight for regularization term in the loss function.
          lambda_super: weight for supervised learning loss in the loss function.

        Output:
          latent:       joint latent representation learned by MUSE.
          reconstruct_x:reconstructed feature matrix corresponding to input data_x.
          reconstruct_y:reconstructed feature matrix corresponding to input data_y.
          latent_x:     modality-specific latent representation corresponding to data_x.
          latent_y:     modality-specific latent representation corresponding to data_y.

        Feng Bao @ Altschuler & Wu Lab @ UCSF 2022.
        Software provided as is under MIT License.
    """

    """ initial parameter setting """
    # parameter setting for neural network
    n_hidden = 128  # number of hidden node in neural network
    learn_rate = 1e-4  # learning rate in the optimization
    batch_size = 64  # number of cells in the training batch
    n_epochs_init = 200  # number of training epoch in model initialization
    print_epochs = 50  # epoch interval to display the current training loss
    cluster_update_epoch = 200  # epoch interval to update modality-specific clusters

    # read data-specific parameters from inputs
    feature_dim_x = data_x.shape[1]
    feature_dim_y = data_y.shape[1]
    n_sample = data_x.shape[0]

    # GPU configuration
    # config = tf.ConfigProto()
    # config.gpu_options.allow_growth = True

    """ construct computation graph using TensorFlow """
    tf.reset_default_graph()

    # raw data from two modalities
    x = tf.placeholder(tf.float32, shape=[None, feature_dim_x], name='input_x')
    y = tf.placeholder(tf.float32, shape=[None, feature_dim_y], name='input_y')

    # labels inputted for references
    ref_label_x = tf.placeholder(tf.float32, shape=[None], name='ref_label_x')
    ref_label_y = tf.placeholder(tf.float32, shape=[None], name='ref_label_y')

    # hyperparameter in triplet loss
    triplet_lambda = tf.placeholder(tf.float32, name='triplet_lambda')
    triplet_margin = tf.placeholder(tf.float32, name='triplet_margin')

    # network architecture
    z, x_hat, y_hat, encode_x, encode_y, loss, \
    reconstruction_error, weight_penalty, \
    trip_loss_x, trip_loss_y = structured_embedding(x,
                                                    y,
                                                    ref_label_x,
                                                    ref_label_y,
                                                    latent_dim,
                                                    triplet_margin,
                                                    n_hidden,
                                                    lambda_regul,
                                                    triplet_lambda)
    # optimization operator
    train_op = tf.train.AdamOptimizer(learn_rate).minimize(loss)
    print('++++++++++ MUSE for multi-modality single-cell analysis ++++++++++')
    """ MUSE optimization """
    total_batch = int(n_sample / batch_size)

    with tf.Session() as sess:

        """ initialization of autoencoder architecture for MUSE """
        print('MUSE initialization')
        # global parameter initialization
        sess.run(tf.global_variables_initializer(), feed_dict={triplet_lambda: 0,
                                                               triplet_margin: 0})

        for epoch in range(n_epochs_init):
            # randomly permute samples
            random_idx = np.random.permutation(n_sample)
            data_train_x = data_x[random_idx, :]
            data_train_y = data_y[random_idx, :]

            for i in range(total_batch):
                # input data batches
                offset = (i * batch_size) % (n_sample)
                batch_x_input = data_train_x[offset:(offset + batch_size), :]
                batch_y_input = data_train_y[offset:(offset + batch_size), :]

                # initialize parameters without self-supervised loss (triplet_lambda=0)
                sess.run(train_op,
                         feed_dict={x: batch_x_input,
                                    y: batch_y_input,
                                    ref_label_x: np.zeros(batch_x_input.shape[0]),
                                    ref_label_y: np.zeros(batch_y_input.shape[0]),
                                    triplet_lambda: 0,
                                    triplet_margin: 0})

            # calculate and print loss terms for current epoch
            if epoch % print_epochs == 0:
                L_total, L_reconstruction, L_weight = \
                    sess.run((loss, reconstruction_error, weight_penalty),
                             feed_dict={x: data_train_x,
                                        y: data_train_y,
                                        ref_label_x: np.zeros(data_train_x.shape[0]),  # no use as triplet_lambda=0
                                        ref_label_y: np.zeros(data_train_y.shape[0]),  # no use as triplet_lambda=0
                                        triplet_lambda: 0,
                                        triplet_margin: 0})

                print(
                    "epoch: %d, \t total loss: %03.5f,\t reconstruction loss: %03.5f,\t sparse penalty: %03.5f"
                    % (epoch, L_total, L_reconstruction, L_weight))

        # estimate the margin for the triplet loss
        latent, reconstruct_x, reconstruct_y = \
            sess.run((z, x_hat, y_hat),
                     feed_dict={x: data_x,
                                y: data_y,
                                ref_label_x: np.zeros(data_x.shape[0]),
                                ref_label_y: np.zeros(data_y.shape[0]),
                                triplet_lambda: 0,
                                triplet_margin: 0})
        latent_pd_matrix = pdist(latent, 'euclidean')
        latent_pd_sort = np.sort(latent_pd_matrix)
        select_top_n = np.int(latent_pd_sort.size * 0.2)
        margin_estimate = np.median(latent_pd_sort[-select_top_n:]) - np.median(latent_pd_sort[:select_top_n])

        # refine MUSE parameters with reference labels and triplet losses
        for epoch in range(n_epochs_init):
            # randomly permute samples
            random_idx = np.random.permutation(n_sample)
            data_train_x = data_x[random_idx, :]
            data_train_y = data_y[random_idx, :]
            label_train_x = label_x[random_idx]
            label_train_y = label_y[random_idx]

            for i in range(total_batch):
                # data batches
                offset = (i * batch_size) % (n_sample)
                batch_x_input = data_train_x[offset:(offset + batch_size), :]
                batch_y_input = data_train_y[offset:(offset + batch_size), :]
                label_x_input = label_train_x[offset:(offset + batch_size)]
                label_y_input = label_train_y[offset:(offset + batch_size)]

                # refine parameters
                sess.run(train_op,
                         feed_dict={x: batch_x_input,
                                    y: batch_y_input,
                                    ref_label_x: label_x_input,
                                    ref_label_y: label_y_input,
                                    triplet_lambda: lambda_super,
                                    triplet_margin: margin_estimate})

            # calculate loss on all input data for current epoch
            if epoch % print_epochs == 0:
                L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y = \
                    sess.run((loss, reconstruction_error, weight_penalty, trip_loss_x, trip_loss_y),
                             feed_dict={x: data_train_x,
                                        y: data_train_y,
                                        ref_label_x: label_train_x,
                                        ref_label_y: label_train_y,
                                        triplet_lambda: lambda_super,
                                        triplet_margin: margin_estimate})

                print(
                    "epoch: %d, \t total loss: %03.5f,\t reconstruction loss: %03.5f,\t sparse penalty: %03.5f,\t x triplet: %03.5f,\t y triplet: %03.5f"
                    % (epoch, L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y))

        # update cluster labels based modality-specific latents
        latent_x, latent_y = \
            sess.run((encode_x, encode_y),
                     feed_dict={x: data_x,
                                y: data_y,
                                ref_label_x: label_x,
                                ref_label_y: label_y,
                                triplet_lambda: lambda_super,
                                triplet_margin: margin_estimate})

        # update cluster labels using PhenoGraph
        label_x_update, _, _ = phenograph.cluster(latent_x, n_jobs= 1)
        label_y_update, _, _ = phenograph.cluster(latent_y, n_jobs= 1)
        print('Finish initialization of MUSE')

        ''' Training of MUSE '''
        for epoch in range(n_epochs):
            # randomly permute samples
            random_idx = np.random.permutation(n_sample)
            data_train_x = data_x[random_idx, :]
            data_train_y = data_y[random_idx, :]
            label_train_x = label_x_update[random_idx]
            label_train_y = label_y_update[random_idx]

            # loop over all batches
            for i in range(total_batch):
                # batch data
                offset = (i * batch_size) % (n_sample)
                batch_x_input = data_train_x[offset:(offset + batch_size), :]
                batch_y_input = data_train_y[offset:(offset + batch_size), :]
                batch_label_x_input = label_train_x[offset:(offset + batch_size)]
                batch_label_y_input = label_train_y[offset:(offset + batch_size)]

                sess.run(train_op,
                         feed_dict={x: batch_x_input,
                                    y: batch_y_input,
                                    ref_label_x: batch_label_x_input,
                                    ref_label_y: batch_label_y_input,
                                    triplet_lambda: lambda_super,
                                    triplet_margin: margin_estimate})

            # calculate and print losses on whole training dataset
            if epoch % print_epochs == 0:
                L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y = \
                    sess.run((loss, reconstruction_error, weight_penalty, trip_loss_x, trip_loss_y),
                             feed_dict={x: data_train_x,
                                        y: data_train_y,
                                        ref_label_x: label_train_x,
                                        ref_label_y: label_train_y,
                                        triplet_lambda: lambda_super,
                                        triplet_margin: margin_estimate})
                # print cost every epoch
                print(
                    "epoch: %d, \t total loss: %03.5f,\t reconstruction loss: %03.5f,\t sparse penalty: %03.5f,\t x triplet loss: %03.5f,\t y triplet loss: %03.5f"
                    % (epoch, L_total, L_reconstruction, L_weight, L_trip_x, L_trip_y))

            # update cluster labels based on new modality-specific latent representations
            if epoch % cluster_update_epoch == 0:
                latent_x, latent_y = \
                    sess.run((encode_x, encode_y),
                             feed_dict={x: data_x,
                                        y: data_y,
                                        ref_label_x: label_x,
                                        ref_label_y: label_y,
                                        triplet_lambda: lambda_super,
                                        triplet_margin: margin_estimate})

                # use PhenoGraph to obtain cluster label
                label_x_update, _, _ = phenograph.cluster(latent_x, n_jobs= 1)
                label_y_update, _, _ = phenograph.cluster(latent_y, n_jobs= 1)

        """ MUSE output """
        latent, reconstruct_x, reconstruct_y, latent_x, latent_y = \
            sess.run((z, x_hat, y_hat, encode_x, encode_y),
                     feed_dict={x: data_x,
                                y: data_y,
                                ref_label_x: label_x,  # no effects to representations
                                ref_label_y: label_y,  # no effects to representations
                                triplet_lambda: lambda_super,
                                triplet_margin: margin_estimate})

        print('++++++++++ MUSE completed ++++++++++')

    return latent, reconstruct_x, reconstruct_y, latent_x, latent_y

# %%
## this is just for testing

################################# loop batch version, random sample
for i in range(5):

  np.random.seed(i)
  indices = np.random.choice(datab_full.shape[0], 25000, replace=False)
  dataa_sub = dataa.iloc[indices,:]
  datab_sub = datab_full[indices,:]
  view_a_label_sub = view_a_label[indices]
  view_b_label_sub = view_b_label[indices]

  muse_feature, reconstruct_x, reconstruct_y, \
    latent_x, latent_y = muse_fit_predict(dataa_sub.to_numpy(),
                                          datab_sub,
                                          view_a_label_sub,
                                          view_b_label_sub,
                                          latent_dim=30,
                                          n_epochs=500,
                                          lambda_regul=5,
                                          lambda_super=5)
  name = 'batch_' + str(i) + '.npy'
  np.save('../data/muse_xton_embedding_' + name, muse_feature)
# Out:
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1770.50745,	 reconstruction loss: 1479.88721,	 sparse penalty: 58.12405
# epoch: 50, 	 total loss: 899.01154,	 reconstruction loss: 868.85266,	 sparse penalty: 6.03177
# epoch: 100, 	 total loss: 845.44275,	 reconstruction loss: 844.69458,	 sparse penalty: 0.14963
# epoch: 150, 	 total loss: 825.85522,	 reconstruction loss: 825.39850,	 sparse penalty: 0.09135
# epoch: 0, 	 total loss: 1433.80237,	 reconstruction loss: 1190.69580,	 sparse penalty: 0.22681,	 x triplet: 24.45541,	 y triplet: 23.93909
# epoch: 50, 	 total loss: 1096.45801,	 reconstruction loss: 871.16827,	 sparse penalty: 0.40197,	 x triplet: 22.41992,	 y triplet: 22.23607
# epoch: 100, 	 total loss: 1084.74194,	 reconstruction loss: 861.36346,	 sparse penalty: 0.34760,	 x triplet: 22.23248,	 y triplet: 22.09562
# epoch: 150, 	 total loss: 1079.02161,	 reconstruction loss: 856.43817,	 sparse penalty: 0.30979,	 x triplet: 22.16194,	 y triplet: 22.04496
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.503740310668945 seconds
# Jaccard graph constructed in 16.595695734024048 seconds
# Wrote graph to binary file in 1.9311389923095703 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.646822
# After 2 runs, maximum modularity is Q = 0.649911
# After 3 runs, maximum modularity is Q = 0.65476
# After 4 runs, maximum modularity is Q = 0.656119
# Louvain completed 24 runs in 17.802303314208984 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 57.37076497077942 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.209380865097046 seconds
# Jaccard graph constructed in 16.5775887966156 seconds
# Wrote graph to binary file in 2.3016626834869385 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.815912
# After 5 runs, maximum modularity is Q = 0.817293
# Louvain completed 25 runs in 20.18136763572693 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 60.467308044433594 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 1077.68542,	 reconstruction loss: 855.48126,	 sparse penalty: 0.28511,	 x triplet loss: 22.09658,	 y triplet loss: 22.05914
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 11.088051557540894 seconds
# Jaccard graph constructed in 18.049811601638794 seconds
# Wrote graph to binary file in 2.8275325298309326 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.670159
# Louvain completed 21 runs in 12.350480318069458 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 55.292038679122925 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 11.328692197799683 seconds
# Jaccard graph constructed in 19.061222314834595 seconds
# Wrote graph to binary file in 2.303037166595459 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.825637
# After 4 runs, maximum modularity is Q = 0.827048
# After 19 runs, maximum modularity is Q = 0.82822
# Louvain completed 39 runs in 31.136894702911377 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 75.63355731964111 seconds
# epoch: 50, 	 total loss: 1071.74866,	 reconstruction loss: 850.27234,	 sparse penalty: 0.27556,	 x triplet loss: 22.02484,	 y triplet loss: 21.99486
# epoch: 100, 	 total loss: 1071.15479,	 reconstruction loss: 849.99207,	 sparse penalty: 0.25493,	 x triplet loss: 22.00032,	 y triplet loss: 21.97729
# epoch: 150, 	 total loss: 1069.46960,	 reconstruction loss: 848.57446,	 sparse penalty: 0.23485,	 x triplet loss: 21.98296,	 y triplet loss: 21.96123
# epoch: 200, 	 total loss: 1068.75854,	 reconstruction loss: 848.08246,	 sparse penalty: 0.21761,	 x triplet loss: 21.96879,	 y triplet loss: 21.94883
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.91094970703125 seconds
# Jaccard graph constructed in 18.408056497573853 seconds
# Wrote graph to binary file in 2.3275930881500244 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.713462
# After 3 runs, maximum modularity is Q = 0.715741
# After 4 runs, maximum modularity is Q = 0.7174
# Louvain completed 24 runs in 20.00977349281311 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 64.37450671195984 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 12.60456109046936 seconds
# Jaccard graph constructed in 18.317787408828735 seconds
# Wrote graph to binary file in 2.11948299407959 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.846412
# Louvain completed 21 runs in 16.13271403312683 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 62.2080340385437 seconds
# epoch: 250, 	 total loss: 1060.96997,	 reconstruction loss: 840.50238,	 sparse penalty: 0.20235,	 x triplet loss: 21.95473,	 y triplet loss: 21.93644
# epoch: 300, 	 total loss: 1058.73425,	 reconstruction loss: 838.45038,	 sparse penalty: 0.19142,	 x triplet loss: 21.94027,	 y triplet loss: 21.92509
# epoch: 350, 	 total loss: 1057.80408,	 reconstruction loss: 837.65778,	 sparse penalty: 0.18261,	 x triplet loss: 21.93149,	 y triplet loss: 21.91515
# epoch: 400, 	 total loss: 1056.61572,	 reconstruction loss: 836.59698,	 sparse penalty: 0.17622,	 x triplet loss: 21.92040,	 y triplet loss: 21.90713
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.583301782608032 seconds
# Jaccard graph constructed in 20.748183488845825 seconds
# Wrote graph to binary file in 2.241166830062866 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.719979
# Louvain completed 21 runs in 14.028547048568726 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 60.83184599876404 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 13.196720123291016 seconds
# Jaccard graph constructed in 21.570637941360474 seconds
# Wrote graph to binary file in 1.97825288772583 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.848922
# After 2 runs, maximum modularity is Q = 0.850734
# After 7 runs, maximum modularity is Q = 0.852521
# Louvain completed 27 runs in 21.726207494735718 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 72.19646835327148 seconds
# epoch: 450, 	 total loss: 1049.38318,	 reconstruction loss: 829.40851,	 sparse penalty: 0.17637,	 x triplet loss: 21.92242,	 y triplet loss: 21.89613
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1771.55981,	 reconstruction loss: 1478.25879,	 sparse penalty: 58.66019
# epoch: 50, 	 total loss: 896.47998,	 reconstruction loss: 870.28650,	 sparse penalty: 5.23869
# epoch: 100, 	 total loss: 858.38361,	 reconstruction loss: 857.89764,	 sparse penalty: 0.09719
# epoch: 150, 	 total loss: 840.08258,	 reconstruction loss: 839.71881,	 sparse penalty: 0.07275
# epoch: 0, 	 total loss: 1252.50000,	 reconstruction loss: 1007.63818,	 sparse penalty: 0.28436,	 x triplet: 24.57067,	 y triplet: 24.11732
# epoch: 50, 	 total loss: 1095.01379,	 reconstruction loss: 875.18903,	 sparse penalty: 0.38368,	 x triplet: 21.86612,	 y triplet: 21.71515
# epoch: 100, 	 total loss: 1089.78369,	 reconstruction loss: 871.74298,	 sparse penalty: 0.30077,	 x triplet: 21.71786,	 y triplet: 21.58952
# epoch: 150, 	 total loss: 1081.41919,	 reconstruction loss: 864.21106,	 sparse penalty: 0.25159,	 x triplet: 21.64701,	 y triplet: 21.54301
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 8.451819658279419 seconds
# Jaccard graph constructed in 24.487616539001465 seconds
# Wrote graph to binary file in 2.45662522315979 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.719819
# After 6 runs, maximum modularity is Q = 0.721402
# Louvain completed 26 runs in 19.43755316734314 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 70.27713894844055 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.338266134262085 seconds
# Jaccard graph constructed in 23.52399730682373 seconds
# Wrote graph to binary file in 2.0250308513641357 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.799897
# Louvain completed 21 runs in 20.454119205474854 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 72.18195962905884 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 1075.97290,	 reconstruction loss: 859.40356,	 sparse penalty: 0.23555,	 x triplet loss: 21.55244,	 y triplet loss: 21.52589
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 7.604003667831421 seconds
# Jaccard graph constructed in 24.28178334236145 seconds
# Wrote graph to binary file in 2.748838186264038 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.725423
# Louvain completed 21 runs in 15.353637218475342 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 66.92222857475281 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 17.97186803817749 seconds
# Jaccard graph constructed in 24.614516973495483 seconds
# Wrote graph to binary file in 2.2640700340270996 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.817054
# After 4 runs, maximum modularity is Q = 0.818934
# After 17 runs, maximum modularity is Q = 0.820848
# Louvain completed 37 runs in 33.65195631980896 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 96.47274231910706 seconds
# epoch: 50, 	 total loss: 1071.29639,	 reconstruction loss: 855.39636,	 sparse penalty: 0.22194,	 x triplet loss: 21.49161,	 y triplet loss: 21.46646
# epoch: 100, 	 total loss: 1066.97205,	 reconstruction loss: 851.37421,	 sparse penalty: 0.20517,	 x triplet loss: 21.46949,	 y triplet loss: 21.44492
# epoch: 150, 	 total loss: 1064.39893,	 reconstruction loss: 849.01941,	 sparse penalty: 0.19133,	 x triplet loss: 21.45547,	 y triplet loss: 21.42909
# epoch: 200, 	 total loss: 1063.92041,	 reconstruction loss: 848.75134,	 sparse penalty: 0.18074,	 x triplet loss: 21.43740,	 y triplet loss: 21.41566
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 8.813868522644043 seconds
# Jaccard graph constructed in 26.753327131271362 seconds
# Wrote graph to binary file in 2.8194427490234375 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.717369
# After 4 runs, maximum modularity is Q = 0.720431
# After 18 runs, maximum modularity is Q = 0.721582
# Louvain completed 38 runs in 29.959517240524292 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 85.69432353973389 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 30.27204918861389 seconds
# Jaccard graph constructed in 26.136965036392212 seconds
# Wrote graph to binary file in 2.171732187271118 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.848149
# After 6 runs, maximum modularity is Q = 0.850092
# Louvain completed 26 runs in 23.444765090942383 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 99.24226331710815 seconds
# epoch: 250, 	 total loss: 1060.72986,	 reconstruction loss: 845.73419,	 sparse penalty: 0.17003,	 x triplet loss: 21.42159,	 y triplet loss: 21.40752
# epoch: 300, 	 total loss: 1059.02759,	 reconstruction loss: 844.14575,	 sparse penalty: 0.16286,	 x triplet loss: 21.41245,	 y triplet loss: 21.40104
# epoch: 350, 	 total loss: 1057.65601,	 reconstruction loss: 842.88281,	 sparse penalty: 0.15680,	 x triplet loss: 21.40384,	 y triplet loss: 21.39399
# epoch: 400, 	 total loss: 1056.00903,	 reconstruction loss: 841.34259,	 sparse penalty: 0.15058,	 x triplet loss: 21.39585,	 y triplet loss: 21.38686
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 9.444189548492432 seconds
# Jaccard graph constructed in 26.638883113861084 seconds
# Wrote graph to binary file in 2.795877695083618 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.710751
# After 3 runs, maximum modularity is Q = 0.713442
# After 15 runs, maximum modularity is Q = 0.715123
# Louvain completed 35 runs in 31.151583194732666 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 88.12736749649048 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 36.04196333885193 seconds
# Jaccard graph constructed in 26.264786958694458 seconds
# Wrote graph to binary file in 1.8920185565948486 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.856119
# After 3 runs, maximum modularity is Q = 0.858598
# After 23 runs, maximum modularity is Q = 0.861071
# Louvain completed 43 runs in 34.397944927215576 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 116.78798341751099 seconds
# epoch: 450, 	 total loss: 1058.70935,	 reconstruction loss: 844.14734,	 sparse penalty: 0.14923,	 x triplet loss: 21.38779,	 y triplet loss: 21.37538
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1765.93054,	 reconstruction loss: 1478.57776,	 sparse penalty: 57.47056
# epoch: 50, 	 total loss: 902.46210,	 reconstruction loss: 876.89618,	 sparse penalty: 5.11319
# epoch: 100, 	 total loss: 856.98285,	 reconstruction loss: 856.52795,	 sparse penalty: 0.09098
# epoch: 150, 	 total loss: 842.18365,	 reconstruction loss: 841.84998,	 sparse penalty: 0.06674
# epoch: 0, 	 total loss: 1209.53503,	 reconstruction loss: 975.88202,	 sparse penalty: 0.28158,	 x triplet: 23.45671,	 y triplet: 22.99231
# epoch: 50, 	 total loss: 1072.47314,	 reconstruction loss: 862.28766,	 sparse penalty: 0.40695,	 x triplet: 20.87855,	 y triplet: 20.75158
# epoch: 100, 	 total loss: 1056.62378,	 reconstruction loss: 847.96472,	 sparse penalty: 0.33443,	 x triplet: 20.74901,	 y triplet: 20.64837
# epoch: 150, 	 total loss: 1050.37170,	 reconstruction loss: 842.68127,	 sparse penalty: 0.28878,	 x triplet: 20.66845,	 y triplet: 20.58085
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 19.902579307556152 seconds
# Jaccard graph constructed in 28.150225400924683 seconds
# Wrote graph to binary file in 3.047402858734131 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.662162
# After 18 runs, maximum modularity is Q = 0.664167
# Louvain completed 38 runs in 28.588836669921875 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 100.06053876876831 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 78.4608371257782 seconds
# Jaccard graph constructed in 28.04399037361145 seconds
# Wrote graph to binary file in 1.8944811820983887 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.70795
# After 3 runs, maximum modularity is Q = 0.713456
# After 14 runs, maximum modularity is Q = 0.715243
# After 28 runs, maximum modularity is Q = 0.717914
# Louvain completed 48 runs in 52.234323501586914 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 181.04352688789368 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 1046.77051,	 reconstruction loss: 839.77155,	 sparse penalty: 0.26506,	 x triplet loss: 20.61080,	 y triplet loss: 20.52393
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 9.762234687805176 seconds
# Jaccard graph constructed in 29.314729928970337 seconds
# Wrote graph to binary file in 2.6113460063934326 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.628783
# After 2 runs, maximum modularity is Q = 0.635857
# After 4 runs, maximum modularity is Q = 0.638497
# Louvain completed 24 runs in 22.23499870300293 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 87.4586591720581 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 13.300530433654785 seconds
# Jaccard graph constructed in 29.19986057281494 seconds
# Wrote graph to binary file in 2.0220489501953125 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.71536
# Louvain completed 21 runs in 21.472322702407837 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 87.32476043701172 seconds
# epoch: 50, 	 total loss: 1041.10632,	 reconstruction loss: 834.78418,	 sparse penalty: 0.25120,	 x triplet loss: 20.54611,	 y triplet loss: 20.46711
# epoch: 100, 	 total loss: 1037.10168,	 reconstruction loss: 831.14948,	 sparse penalty: 0.23054,	 x triplet loss: 20.51517,	 y triplet loss: 20.44472
# epoch: 150, 	 total loss: 1035.18079,	 reconstruction loss: 829.53949,	 sparse penalty: 0.21494,	 x triplet loss: 20.48808,	 y triplet loss: 20.42524
# epoch: 200, 	 total loss: 1031.62024,	 reconstruction loss: 826.20721,	 sparse penalty: 0.20189,	 x triplet loss: 20.47058,	 y triplet loss: 20.41014
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.597092628479004 seconds
# Jaccard graph constructed in 31.228705167770386 seconds
# Wrote graph to binary file in 2.694842576980591 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.676176
# After 5 runs, maximum modularity is Q = 0.678275
# Louvain completed 25 runs in 22.65269112586975 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 89.4473602771759 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 93.10065650939941 seconds
# Jaccard graph constructed in 31.04967951774597 seconds
# Wrote graph to binary file in 2.5378146171569824 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.710343
# After 2 runs, maximum modularity is Q = 0.714748
# After 4 runs, maximum modularity is Q = 0.717612
# After 6 runs, maximum modularity is Q = 0.720219
# Louvain completed 26 runs in 30.71491026878357 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 179.27980875968933 seconds
# epoch: 250, 	 total loss: 1030.32556,	 reconstruction loss: 825.17432,	 sparse penalty: 0.19700,	 x triplet loss: 20.43772,	 y triplet loss: 20.39554
# epoch: 300, 	 total loss: 1027.66821,	 reconstruction loss: 822.67664,	 sparse penalty: 0.18772,	 x triplet loss: 20.42642,	 y triplet loss: 20.38419
# epoch: 350, 	 total loss: 1028.13586,	 reconstruction loss: 823.28723,	 sparse penalty: 0.17951,	 x triplet loss: 20.41529,	 y triplet loss: 20.37493
# epoch: 400, 	 total loss: 1025.13745,	 reconstruction loss: 820.41614,	 sparse penalty: 0.17204,	 x triplet loss: 20.40529,	 y triplet loss: 20.36692
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 9.800575494766235 seconds
# Jaccard graph constructed in 32.78770923614502 seconds
# Wrote graph to binary file in 2.558650255203247 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.681635
# After 15 runs, maximum modularity is Q = 0.682829
# After 33 runs, maximum modularity is Q = 0.68476
# Louvain completed 53 runs in 46.22388792037964 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 115.23205590248108 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 43.877689599990845 seconds
# Jaccard graph constructed in 30.507280588150024 seconds
# Wrote graph to binary file in 1.9943716526031494 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.713868
# After 2 runs, maximum modularity is Q = 0.716841
# After 6 runs, maximum modularity is Q = 0.72185
# Louvain completed 26 runs in 30.34405779838562 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 130.51917362213135 seconds
# epoch: 450, 	 total loss: 1024.06775,	 reconstruction loss: 819.46552,	 sparse penalty: 0.17105,	 x triplet loss: 20.39244,	 y triplet loss: 20.35695
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1768.46472,	 reconstruction loss: 1481.43616,	 sparse penalty: 57.40571
# epoch: 50, 	 total loss: 901.26361,	 reconstruction loss: 870.62238,	 sparse penalty: 6.12825
# epoch: 100, 	 total loss: 851.40894,	 reconstruction loss: 850.89252,	 sparse penalty: 0.10328
# epoch: 150, 	 total loss: 833.30487,	 reconstruction loss: 832.92914,	 sparse penalty: 0.07514
# epoch: 0, 	 total loss: 1244.32910,	 reconstruction loss: 1001.44916,	 sparse penalty: 0.27290,	 x triplet: 24.41815,	 y triplet: 23.88494
# epoch: 50, 	 total loss: 1082.79407,	 reconstruction loss: 865.85663,	 sparse penalty: 0.39263,	 x triplet: 21.54921,	 y triplet: 21.44566
# epoch: 100, 	 total loss: 1077.08667,	 reconstruction loss: 861.63232,	 sparse penalty: 0.33417,	 x triplet: 21.43315,	 y triplet: 21.32355
# epoch: 150, 	 total loss: 1068.18591,	 reconstruction loss: 853.29523,	 sparse penalty: 0.29834,	 x triplet: 21.39348,	 y triplet: 21.28632
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 39.53329372406006 seconds
# Jaccard graph constructed in 33.72168827056885 seconds
# Wrote graph to binary file in 3.9888854026794434 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.60605
# Louvain completed 21 runs in 19.598812341690063 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 122.24392032623291 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 13.870426416397095 seconds
# Jaccard graph constructed in 35.32652926445007 seconds
# Wrote graph to binary file in 2.292210340499878 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.766059
# After 8 runs, maximum modularity is Q = 0.767504
# Louvain completed 28 runs in 35.1239492893219 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 111.53403449058533 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 1058.07507,	 reconstruction loss: 843.50092,	 sparse penalty: 0.28187,	 x triplet loss: 21.34587,	 y triplet loss: 21.28708
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.717998504638672 seconds
# Jaccard graph constructed in 34.69157862663269 seconds
# Wrote graph to binary file in 2.79597806930542 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.592042
# After 3 runs, maximum modularity is Q = 0.596166
# Louvain completed 23 runs in 23.830042600631714 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 96.3738329410553 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.267264604568481 seconds
# Jaccard graph constructed in 33.59955430030823 seconds
# Wrote graph to binary file in 2.1476006507873535 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.778318
# Louvain completed 21 runs in 21.89419913291931 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 91.85964179039001 seconds
# epoch: 50, 	 total loss: 1056.59814,	 reconstruction loss: 842.78741,	 sparse penalty: 0.27634,	 x triplet loss: 21.26583,	 y triplet loss: 21.21998
# epoch: 100, 	 total loss: 1048.61719,	 reconstruction loss: 835.13519,	 sparse penalty: 0.25556,	 x triplet loss: 21.24282,	 y triplet loss: 21.19803
# epoch: 150, 	 total loss: 1045.27783,	 reconstruction loss: 832.10120,	 sparse penalty: 0.23761,	 x triplet loss: 21.21991,	 y triplet loss: 21.17780
# epoch: 200, 	 total loss: 1043.70947,	 reconstruction loss: 830.78271,	 sparse penalty: 0.22156,	 x triplet loss: 21.20198,	 y triplet loss: 21.16183
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.871376514434814 seconds
# Jaccard graph constructed in 33.85512161254883 seconds
# Wrote graph to binary file in 3.0111820697784424 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.596381
# After 2 runs, maximum modularity is Q = 0.599544
# After 15 runs, maximum modularity is Q = 0.601707
# Louvain completed 35 runs in 34.30886173248291 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 107.31580376625061 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 55.89139246940613 seconds
# Jaccard graph constructed in 35.307594537734985 seconds
# Wrote graph to binary file in 2.2004947662353516 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.795639
# Louvain completed 21 runs in 22.90503215789795 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 141.4944713115692 seconds
# epoch: 250, 	 total loss: 1039.46143,	 reconstruction loss: 826.71234,	 sparse penalty: 0.20869,	 x triplet loss: 21.19189,	 y triplet loss: 21.14924
# epoch: 300, 	 total loss: 1037.18970,	 reconstruction loss: 824.59991,	 sparse penalty: 0.19802,	 x triplet loss: 21.18010,	 y triplet loss: 21.13984
# epoch: 350, 	 total loss: 1034.04138,	 reconstruction loss: 821.61066,	 sparse penalty: 0.18957,	 x triplet loss: 21.16623,	 y triplet loss: 21.13034
# epoch: 400, 	 total loss: 1033.46545,	 reconstruction loss: 821.14972,	 sparse penalty: 0.18237,	 x triplet loss: 21.15819,	 y triplet loss: 21.12258
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 11.61109209060669 seconds
# Jaccard graph constructed in 44.682074546813965 seconds
# Wrote graph to binary file in 3.3146800994873047 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.582497
# After 2 runs, maximum modularity is Q = 0.586983
# After 9 runs, maximum modularity is Q = 0.588165
# Louvain completed 29 runs in 37.40324354171753 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 127.6392970085144 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.697559595108032 seconds
# Jaccard graph constructed in 42.15866732597351 seconds
# Wrote graph to binary file in 2.3860535621643066 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.797089
# After 4 runs, maximum modularity is Q = 0.798123
# After 5 runs, maximum modularity is Q = 0.7997
# After 15 runs, maximum modularity is Q = 0.801448
# Louvain completed 35 runs in 51.40357828140259 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 137.8395516872406 seconds
# epoch: 450, 	 total loss: 1030.42065,	 reconstruction loss: 818.30267,	 sparse penalty: 0.18261,	 x triplet loss: 21.13407,	 y triplet loss: 21.10693
# ++++++++++ MUSE completed ++++++++++
# ++++++++++ MUSE for multi-modality single-cell analysis ++++++++++
# MUSE initialization
# epoch: 0, 	 total loss: 1781.79028,	 reconstruction loss: 1479.68066,	 sparse penalty: 60.42191
# epoch: 50, 	 total loss: 914.10730,	 reconstruction loss: 880.36121,	 sparse penalty: 6.74922
# epoch: 100, 	 total loss: 849.43988,	 reconstruction loss: 848.83752,	 sparse penalty: 0.12048
# epoch: 150, 	 total loss: 833.93005,	 reconstruction loss: 833.54028,	 sparse penalty: 0.07796
# epoch: 0, 	 total loss: 1295.37305,	 reconstruction loss: 1048.01794,	 sparse penalty: 0.26195,	 x triplet: 24.87371,	 y triplet: 24.33538
# epoch: 50, 	 total loss: 1091.56079,	 reconstruction loss: 867.66364,	 sparse penalty: 0.39148,	 x triplet: 22.28186,	 y triplet: 22.10608
# epoch: 100, 	 total loss: 1090.46179,	 reconstruction loss: 868.29663,	 sparse penalty: 0.32838,	 x triplet: 22.13008,	 y triplet: 21.97458
# epoch: 150, 	 total loss: 1086.63806,	 reconstruction loss: 865.40106,	 sparse penalty: 0.28548,	 x triplet: 22.03477,	 y triplet: 21.92716
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 11.239810705184937 seconds
# Jaccard graph constructed in 40.9538996219635 seconds
# Wrote graph to binary file in 2.936002731323242 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.707895
# After 3 runs, maximum modularity is Q = 0.709445
# Louvain completed 23 runs in 24.112680912017822 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 110.09072971343994 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 64.31728076934814 seconds
# Jaccard graph constructed in 39.2672016620636 seconds
# Wrote graph to binary file in 2.3741228580474854 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.813894
# After 2 runs, maximum modularity is Q = 0.815083
# Louvain completed 22 runs in 28.38765048980713 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 165.29365491867065 seconds
# Finish initialization of MUSE
# epoch: 0, 	 total loss: 1083.99890,	 reconstruction loss: 863.17700,	 sparse penalty: 0.25759,	 x triplet loss: 21.97039,	 y triplet loss: 21.93641
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.810517311096191 seconds
# Jaccard graph constructed in 41.455552101135254 seconds
# Wrote graph to binary file in 2.6655519008636475 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.707819
# Louvain completed 21 runs in 20.023538827896118 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 106.23607754707336 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 9.955719947814941 seconds
# Jaccard graph constructed in 39.67458248138428 seconds
# Wrote graph to binary file in 2.125744104385376 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.817624
# After 5 runs, maximum modularity is Q = 0.82096
# After 15 runs, maximum modularity is Q = 0.822671
# Louvain completed 35 runs in 42.68135452270508 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 125.85181212425232 seconds
# epoch: 50, 	 total loss: 1081.68982,	 reconstruction loss: 861.54694,	 sparse penalty: 0.24651,	 x triplet loss: 21.90477,	 y triplet loss: 21.87730
# epoch: 100, 	 total loss: 1078.96606,	 reconstruction loss: 859.10315,	 sparse penalty: 0.22691,	 x triplet loss: 21.88544,	 y triplet loss: 21.86024
# epoch: 150, 	 total loss: 1077.17407,	 reconstruction loss: 857.55444,	 sparse penalty: 0.20943,	 x triplet loss: 21.86879,	 y triplet loss: 21.84571
# epoch: 200, 	 total loss: 1074.55457,	 reconstruction loss: 855.09753,	 sparse penalty: 0.19580,	 x triplet loss: 21.85931,	 y triplet loss: 21.83629
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.01651644706726 seconds
# Jaccard graph constructed in 43.87714147567749 seconds
# Wrote graph to binary file in 2.4156911373138428 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.698973
# After 2 runs, maximum modularity is Q = 0.700235
# After 8 runs, maximum modularity is Q = 0.70141
# Louvain completed 28 runs in 32.13682150840759 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 119.44212532043457 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 210.62942719459534 seconds
# Jaccard graph constructed in 42.86331653594971 seconds
# Wrote graph to binary file in 2.4680533409118652 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.838003
# After 2 runs, maximum modularity is Q = 0.841239
# Louvain completed 22 runs in 26.13739013671875 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 314.6241693496704 seconds
# epoch: 250, 	 total loss: 1067.80371,	 reconstruction loss: 848.36743,	 sparse penalty: 0.19094,	 x triplet loss: 21.86470,	 y triplet loss: 21.83162
# epoch: 300, 	 total loss: 1064.80029,	 reconstruction loss: 845.58307,	 sparse penalty: 0.18265,	 x triplet loss: 21.84586,	 y triplet loss: 21.81494
# epoch: 350, 	 total loss: 1062.46252,	 reconstruction loss: 843.40088,	 sparse penalty: 0.17511,	 x triplet loss: 21.83306,	 y triplet loss: 21.80415
# epoch: 400, 	 total loss: 1060.70093,	 reconstruction loss: 841.76233,	 sparse penalty: 0.16762,	 x triplet loss: 21.82388,	 y triplet loss: 21.79622
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 9.897135496139526 seconds
# Jaccard graph constructed in 42.0938937664032 seconds
# Wrote graph to binary file in 2.7352633476257324 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.721528
# After 3 runs, maximum modularity is Q = 0.725064
# After 14 runs, maximum modularity is Q = 0.726676
# Louvain completed 34 runs in 38.34710884094238 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 125.50752878189087 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.66583514213562 seconds
# Jaccard graph constructed in 42.479851961135864 seconds
# Wrote graph to binary file in 2.4644575119018555 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.846173
# After 2 runs, maximum modularity is Q = 0.848031
# Louvain completed 22 runs in 24.88404655456543 seconds
# Sorting communities by size, please wait ...
# PhenoGraph complete in 113.69895124435425 seconds
# epoch: 450, 	 total loss: 1058.74329,	 reconstruction loss: 839.89917,	 sparse penalty: 0.16116,	 x triplet loss: 21.81593,	 y triplet loss: 21.79173
# ++++++++++ MUSE completed ++++++++++
